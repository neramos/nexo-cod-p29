# %%
import numpy as np
import matplotlib.pyplot as plt
from math import isqrt

# %matplotlib inline

def is_prime(n):
    if n < 2: return False
    if n in (2, 3): return True
    if n % 2 == 0 or n % 3 == 0: return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0: return False
        i += 6
    return True

N = 30000   # Increase for denser arms
#theta = np.arange(1, N+1, dtype=float)
#theta = np.arange(1, N+1, dtype=float) * np.log(np.arange(1, N+1, dtype=float))
r = theta
x = r * np.cos(theta)
y = r * np.sin(theta)

# All points - background
plt.figure(figsize=(13, 13), facecolor='black')
plt.scatter(x, y, c='#333333', s=1.0, alpha=0.6)   # dim gray background

# Primes overlaid in bright color
primes = np.array([is_prime(i) for i in range(1, N+1)])
plt.scatter(x[primes], y[primes], c='#00ffff', s=2.5, alpha=0.95)

plt.title(f"Polar Spiral: All integers (gray) + Primes (cyan)\n1 to {N:,}", color='white', fontsize=15)
plt.axis('off')
plt.tight_layout()
plt.show()
